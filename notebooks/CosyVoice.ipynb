# %% [markdown]
# <a href="https://colab.research.google.com/github/nezha001/calculator-ywsj/blob/main/notebooks/CosyVoice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 一键运行 CosyVoice
# !git clone --recursive https://github.com/KevinWang676/CosyVoice.git
# %cd CosyVoice
# !pip install -r requirements.txt
# !mkdir -p pretrained_models
# !git clone https://www.modelscope.cn/iic/CosyVoice-300M.git pretrained_models/CosyVoice-300M
# !export PYTHONPATH=third_party/Matcha-TTS
# !python3 webui_colab.py
# Out:
# Cloning into 'CosyVoice'...
# remote: Enumerating objects: 1933, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Total 1933 (delta 1), reused 1 (delta 1), pack-reused 1931 (from 2)
# Receiving objects: 100% (1933/1933), 1.57 MiB | 18.48 MiB/s, done.
# Resolving deltas: 100% (1142/1142), done.
# Submodule 'third_party/Matcha-TTS' (https://github.com/shivammehta25/Matcha-TTS.git) registered for path 'third_party/Matcha-TTS'
# Cloning into '/content/CosyVoice/third_party/Matcha-TTS'...
# remote: Enumerating objects: 1081, done.
# remote: Counting objects: 100% (481/481), done.
# remote: Compressing objects: 100% (172/172), done.
# remote: Total 1081 (delta 392), reused 310 (delta 309), pack-reused 600 (from 3)
# Receiving objects: 100% (1081/1081), 64.11 MiB | 29.24 MiB/s, done.
# Resolving deltas: 100% (524/524), done.
# Submodule path 'third_party/Matcha-TTS': checked out 'dd9105b34bf2be2230f4aa1e4769fb586a3c824e'
# /content/CosyVoice
# ...
